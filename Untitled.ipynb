# %%
#Load Libraries
import pandas as pd

# %%
#Load Dataset
dataset = pd.read_csv('CO2-Emissions_Canada.csv')
dataset.head()
# Out:
#     Make       Model Category Vehicle Class  Engine Size(L)  Cylinders  \
# 0  ACURA         ILX    Sedan       COMPACT             2.0          4
# 1  ACURA         ILX    Sedan       COMPACT             2.4          4
# 2  ACURA  ILX HYBRID    Sedan       COMPACT             1.5          4
# 3  ACURA     MDX 4WD    Truck   SUV - SMALL             3.5          6
# 4  ACURA     RDX AWD    Truck   SUV - SMALL             3.5          6
#
#   Transmission Type  No of Gears Fuel Type  Fuel Consumption City (L/100 km)  \
# 0                AS            5         Z                               9.9
# 1                 M            6         Z                              11.2
# 2                AV            7         Z                               6.0
# 3                AS            6         Z                              12.7
# 4                AS            6         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# ...

# %%
dataset.describe()
# Out:
#        Engine Size(L)    Cylinders  No of Gears  \
# count     7044.000000  7044.000000  7044.000000
# mean         3.206502     5.675752     6.885860
# std          1.360041     1.839098     1.208625
# min          0.900000     3.000000     4.000000
# 25%          2.000000     4.000000     6.000000
# 50%          3.000000     6.000000     6.000000
# 75%          3.800000     6.000000     8.000000
# max          8.400000    16.000000    10.000000
#
#        Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# count                       7044.000000                      7044.000000
# mean                          12.747061                         9.136996
# std                            3.420669                         2.202274
# min                            4.200000                         4.000000
# 25%                           10.300000                         7.600000
# 50%                           12.200000                         8.700000
# ...
